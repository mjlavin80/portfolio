# %%
color_set = ['#FAEBD7', '#D3D3D3', '#FF1493', '#FF69B4', '#DDA0DD', '#FFA07A', '#BA55D3', '#FF0000', '#4B0082', '#800000', '#C71585','#7B68EE', '#191970']
LawX = [69487,65929, 37754 , 86340, 60304, 54620, 29237, 56580,36782, 36485, 33772, 24997,  12063 , 29809, 26482.00, 39919, 28989, 47559.00, 40753, 40409, 55419.00, 41547.00, 23361.00,57887,66699]
LawY = [3,4,1,7,4,7,3,8,5,3,5,2,7,5,3,5,7,5,5,8,5,5,4,6,6]
AcademiaY = [7,4,3,6,5,6,7,5,6,8]
AcademiaX = [38548,23988,38207,26645,55223 ,35968,51725,26682,74893,43636]
PsychologyY = [5,7,3]
PsychologyX = [27094, 30768, 45360]
MedicineY = [6,6,7]
MedicineX = [30768.00, 45360, 55080]
EngineerX = [28418.00,28891.00]
EngineerY = [4,6]
EntertainmentX = [41507.00,53539.00,28317.00,52804.00,42390.00]
EntertainmentY = [6,4,5,6,3]
FinanceX = [52010.00,17134,30038,62635,30147.00,32159,21597,76624,55550,57213]
FinanceY = [10,7,3,7,2,6,5,7,9,10]
HumanAffairsX = [48652,43185,23152,43664,48441,61152,41466,38022,25589,109031]
HumanAffairsY = [6,7,5,5,7,3,9,4,5,6]
UndecidedX = [50948, 53923,17378]
UndecidedY = [5,5,7]
SocialX =[46166,30973.00]
SocialY = [6,7]
AthleteX = [53940]
AthleteY = [9]
TechX =[42096]
TechY = [3]

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np

trace0 = go.Scatter(
    x = LawX,
    y = LawY,
    name = 'Law',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[0],
    )
)

trace1 = go.Scatter(
    x = AcademiaX,
    y = AcademiaY,
    name = 'Academia',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[1],
    )
)

trace2 = go.Scatter(
    x = PsychologyX,
    y = PsychologyY,
    name = 'Psych',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[2],
    )
)

trace3 = go.Scatter(
    x = MedicineX,
    y = MedicineY,
    name = 'Medicine',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[3],
    )
)

trace4 = go.Scatter(
    x = EngineerX,
    y = EngineerY,
    name = 'Engineer',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[4],
    )
)

trace5 = go.Scatter(
    x = EntertainmentX,
    y = EntertainmentY,
    name = 'Entertainment',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[5],
    )
)

trace6 = go.Scatter(
    x = FinanceX,
    y = FinanceY,
    name = 'Finance',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[6],
    )
)

trace7 = go.Scatter(
    x = HumanAffairsX,
    y = HumanAffairsY,
    name = 'Human Affairs',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[7],
    )
)

trace8 = go.Scatter(
    x = UndecidedX,
    y = UndecidedY,
    name = 'Undecided',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[8],
    )
)

trace9 = go.Scatter(
    x = SocialX,
    y = SocialY,
    name = 'Social Work',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[9],
    )
)

trace10 = go.Scatter(
    x = AthleteX,
    y = AthleteY,
    name = 'Pro Athlete',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[10],
    )
)

trace11 = go.Scatter(
    x = TechX,
    y = TechY,
    name = 'Tech',
    mode = 'markers',
    marker = dict(
        size = 10,
        color = color_set[11],
    )
)


data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10, trace11]

layout = dict(title = 'Expected Happiness and Income',
              yaxis = dict(zeroline = False,
                          title= 'Expected Happiness'),
              xaxis = dict(zeroline = False,
                          title='Average Hometown Income')
             )

fig = dict(data=data, layout=layout)
py.iplot(fig, filename='styled-scatter')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~eac85/171.embed" height="525px" width="100%"></iframe>
